# %% [markdown]
# # Segmentation Stability Analysis
#
# Evaluation-only companion to `Segmentation_Modeling.ipynb`. This notebook runs the reproducible stability script, which reuses the same customer feature matrix construction and final K-Means settings without changing served segmentation artifacts.

# %%
# %run segmentation_stability_analysis.py
